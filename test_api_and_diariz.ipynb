# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.EvaProjectIntagration import EvaProjectIntegration

epi = EvaProjectIntegration(logging_flag=1)
epi.create_task(responsible_name="Коля")
# Out:
# 2024-09-04 22:24:12,824 - DEBUG - Starting new HTTPS connection (1): reu-im-g-v-plehanova.evateam.ru:443
# 2024-09-04 22:24:12,916 - DEBUG - https://reu-im-g-v-plehanova.evateam.ru:443 "POST /api/ HTTP/11" 200 None
# 2024-09-04 22:24:12,917 - DEBUG - Ближайший найденный пользователь по Коля: Новый Николай
# 2024-09-04 22:24:12,918 - DEBUG - Starting new HTTPS connection (1): reu-im-g-v-plehanova.evateam.ru:443
# 2024-09-04 22:24:13,227 - DEBUG - https://reu-im-g-v-plehanova.evateam.ru:443 "POST /api/ HTTP/11" 200 845
# 2024-09-04 22:24:13,229 - DEBUG - Статус по CmfTask.create : 200
# ...

# %%
from src.SpeechProcessing import SpeechProcessing

# Пример использования:
speech_processor = SpeechProcessing()

# Авторизация
speech_processor.authorization()

# Загрузка моделей
speech_processor.load_diarization_model()
speech_processor.load_asr_model()

# Загрузка данных
sample = speech_processor.load_dataset()

# Обработка аудио
asr_result, diarization_result = speech_processor.process_audio(sample)

# Комбинированная обработка
combined_result = speech_processor.combine_pipelines(sample)

# Форматирование результата
transcription = speech_processor.format_as_transcription(combined_result)
print(transcription)
# Out:
# 2024-09-04 22:25:18,900 - DEBUG - Starting new HTTPS connection (1): huggingface.co:443
# 2024-09-04 22:25:19,197 - DEBUG - https://huggingface.co:443 "GET /api/whoami-v2 HTTP/11" 200 400
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (osxkeychain).
# Your token has been saved to /Users/pelageya/.cache/huggingface/token
# Login successful
# 2024-09-04 22:25:19,599 - DEBUG - https://huggingface.co:443 "HEAD /pyannote/speaker-diarization/resolve/2.1/config.yaml HTTP/11" 200 0
# 2024-09-04 22:25:19,850 - DEBUG - Registered checkpoint save hook for _speechbrain_save
# 2024-09-04 22:25:19,850 - DEBUG - Registered checkpoint load hook for _speechbrain_load
# 2024-09-04 22:25:19,851 - DEBUG - Registered checkpoint save hook for save
# 2024-09-04 22:25:19,851 - DEBUG - Registered checkpoint load hook for load
# 2024-09-04 22:25:19,853 - DEBUG - Registered checkpoint save hook for _save
# ...

# %%
transcription
# Out:
# "SPEAKER_01 (0.0, 15.5):  The second and importance is as follows. Sovereignty may be defined to be the right of making laws. In France, the king really exercises a portion of the sovereign power, since the laws have no weight.\n\nSPEAKER_00 (15.5, 21.3):  He was in a favored state of mind, owing to the blight his wife's action threatened to cast upon his entire future."
